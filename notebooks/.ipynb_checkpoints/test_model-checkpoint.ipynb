# %%
import numpy as np
import pickle

from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
model = load_model("../models/sentiment_lstm_model.keras")

print("Model loaded successfully")
# Out:
# Model loaded successfully
# C:\Users\abhin\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 8 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
with open("../models/tokenizer.pkl", "rb") as f:
    tokenizer = pickle.load(f)

print("Tokenizer loaded successfully")
# Out:
# Tokenizer loaded successfully

# %%
# Test review
review = ["This movie is fantastic"]

# Convert to sequence
seq = tokenizer.texts_to_sequences(review)

# Pad sequence
pad = pad_sequences(seq, maxlen=200)

# Predict
prediction = model.predict(pad)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step

# %%
if prediction[0][0] > 0.5:
    print("Positive Review")
else:
    print("Negative Review")
# Out:
# Positive Review
